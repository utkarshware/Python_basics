# %%
x = [1,2,3]
y =2
z=3

# %%
import pdb

# %%
x = [1,2,3]
y =2
z=3
result_one= y+z
pdb.set_trace()
result_two= y+x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 z=3
#       4 result_one= y+z
# ----> 5 pdb.set_trace()
#       6 result_two= y+x
#
# NameError: name 'pdb' is not defined
