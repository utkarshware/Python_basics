# %%
x = [1,2,3]
y =2
z=3

# %%
import pdb

# %%
x = [1,2,3]
y =2
z=3
result_one= y+z
pdb.set_trace()
result_two= y+x
# Out:
# > c:\users\51ngh\appdata\local\temp\ipykernel_6492\2412144344.py(5)<module>()
#       2 y =2
#       3 z=3
#       4 result_one= y+z
# ----> 5 pdb.set_trace()
#       6 result_two= y+x
#
# 5
# 2
# 3
# 3
# *** NameError: name 'escape' is not defined
# *** NameError: name 'Escpae' is not defined
# *** NameError: name 'Escape' is not defined
