# %%
from collections import Counter

# %%
mylist = [1,2,2,3,4,4,4,5,5,5,5]

# %%
Counter(mylist)
# Out:
# Counter({5: 4, 4: 3, 2: 2, 1: 1, 3: 1})

# %%
mylist=["a","a",10,10,10]

# %%
Counter(mylist)
# Out:
# Counter({10: 3, 'a': 2})

# %%
Counter("aaaaabbbhdjsjsds")
# Out:
# Counter({'a': 5, 'b': 3, 's': 3, 'd': 2, 'j': 2, 'h': 1})

# %%
sentence = "How many times does each word show up in this sentence word word show up"

# %%
Counter(sentence.lower().split())
# Out:
# Counter({'word': 3,
#          'show': 2,
#          'up': 2,
#          'how': 1,
#          'many': 1,
#          'times': 1,
#          'does': 1,
#          'each': 1,
#          'in': 1,
#          'this': 1,
#          'sentence': 1})

# %%
letters = "aaaljdnsldsldhjbbsdsdsdxxxxxccccccc"

# %%
c = Counter(letters)

# %%
c
# Out:
# Counter({'c': 7,
#          'd': 6,
#          's': 5,
#          'x': 5,
#          'a': 3,
#          'l': 3,
#          'j': 2,
#          'b': 2,
#          'n': 1,
#          'h': 1})

# %%
c.most_common()
# Out:
# [('c', 7),
#  ('d', 6),
#  ('s', 5),
#  ('x', 5),
#  ('a', 3),
#  ('l', 3),
#  ('j', 2),
#  ('b', 2),
#  ('n', 1),
#  ('h', 1)]

# %%
c
# Out:
# Counter({'c': 7,
#          'd': 6,
#          's': 5,
#          'x': 5,
#          'a': 3,
#          'l': 3,
#          'j': 2,
#          'b': 2,
#          'n': 1,
#          'h': 1})

# %%
list(c)
# Out:
# ['a', 'l', 'j', 'd', 'n', 's', 'h', 'b', 'x', 'c']

# %%
from collections import defaultdict

# %%
d = {"a":10}

# %%
d["a"]
# Out:
# 10

# %%
d["Wrong"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 d["Wrong"]
#
# KeyError: 'Wrong'

# %%
d = defaultdict(lambda:"none")

# %%
d["Correct"]=100

# %%
d["Correct"]
# Out:
# 100

# %%
d["Utkarsh"]
# Out:
# 'none'

# %%
d
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'Correct': 100, 'Utkarsh': 'none'})

# %%
mytuple = (1,2,3)

# %%
mytuple[0]
# Out:
# 1

# %%
from collections import namedtuple

# %%
Dog = namedtuple("Dog",["age","breed","name"])

# %%
sammy = Dog(age=5,breed="Husky",name="Sammy")

# %%
print(sammy)
# Out:
# Dog(age=5, breed='Husky', name='Sammy')

# %%
type(sammy)
# Out:
# __main__.Dog

# %%
sammy[1]
# Out:
# 'Husky'
