# %%
import datetime

# %%
mytime = datetime.time(22,43,1,20)

# %%
mytime.minute
# Out:
# 43

# %%
mytime.hour
# Out:
# 22

# %%
print(mytime)
# Out:
# 22:43:01.000020

# %%
mytime.microsecond
# Out:
# 20

# %%
type(mytime)
# Out:
# datetime.time

# %%
today = datetime.date.today()

# %%
print(today)
# Out:
# 2025-12-16

# %%
today.ctime()
# Out:
# 'Tue Dec 16 00:00:00 2025'

# %%
from datetime import datetime

# %%
mydatetime = datetime(2020,5,17,12,30,45)

# %%
print(mydatetime)
# Out:
# 2020-05-17 12:30:45

# %%
mydatetime.replace(year=2025,month=12)
# Out:
# datetime.datetime(2025, 12, 17, 12, 30, 45)

# %%
print(mydatetime)
# Out:
# 2020-05-17 12:30:45

# %%
from datetime import date

# %%
date1 = date(2025,12,16)
date2 = date(2025,4,21)

# %%
result =date1 - date2

# %%
print(result)
# Out:
# 239 days, 0:00:00

# %%
type(result)
# Out:
# datetime.timedelta

# %%
result.days
# Out:
# 239

# %%
datetime1= datetime(2025,12,16,10,30)
datetime2= datetime(2025,4,21,8,15)

# %%
print(datetime1-datetime2)
# Out:
# 239 days, 2:15:00

# %%
mydiff = datetime1 - datetime2

# %%
mydiff.seconds
# Out:
# 8100

# %%
mydiff.total_seconds()
# Out:
# 20657700.0
