# %%
def func():
    return 1

# %%
func()
# Out:
# 1

# %%
func
# Out:
# <function __main__.func()>

# %%
def hello():
    return "Hello World!"

# %%
hello()
# Out:
# 'Hello World!'

# %%
hello
# Out:
# <function __main__.hello()>

# %%
greet = hello

# %%
greet()
# Out:
# 'Hello World!'

# %%
del hello

# %%
greet()
# Out:
# 'Hello World!'

# %%
def hello(name= "Utkarsh"):
    print("The hello() function has been executed!")
    def greet():
        return"\t This is greet() function inside hello()"
    def welcome():
        return"\t This is welcome() function inside hello()"
    
    print("I am going to return a function!")
    if name == "Utkarsh":
        return greet
    else:
        return welcome

# %%
hello()
# Out:
# The hello() function has been executed!
# I am going to return a function!
# <function __main__.hello.<locals>.greet()>

# %%
my_new_func = hello("Utkarsh")
# Out:
# The hello() function has been executed!
# I am going to return a function!

# %%
my_new_func()
# Out:
# '\t This is greet() function inside hello()'

# %%
def cool():
    def super_cool():
        return "I am very cool!"
    
    return super_cool

# %%
some_func = cool()

# %%
some_func
# Out:
# <function __main__.cool.<locals>.super_cool()>

# %%
some_func()
# Out:
# 'I am very cool!'

# %%
def hello ():
    return "Hi Utkarsh!"

# %%
def other (func):
    print("Other code runs here!")
    print(func())

# %%
other(hello)
# Out:
# Other code runs here!
# Hi Utkarsh!

# %%
hello()
# Out:
# 'Hi Utkarsh!'

# %%
def new_decorator(func):
    def wrap_func():
        print("some extra code, before the original function")
        func()
        print("some extra code, after the original function")
    return wrap_func

# %%
def func_needs_decorator():
    print("I want to be decorated!!")

# %%
func_needs_decorator()
# Out:
# I want to be decorated!!

# %%
decorated_func = new_decorator(func_needs_decorator)

# %%
print(decorated_func)
# Out:
# <function new_decorator.<locals>.wrap_func at 0x0000018487AE4B80>

# %%
decorated_func()
# Out:
# some extra code, before the original function
# I want to be decorated!!
# some extra code, after the original function

# %%
@new_decorator
def func_needs_decorator():
    print("I want to be decorated!!")

# %%
func_needs_decorator()
# Out:
# some extra code, before the original function
# I want to be decorated!!
# some extra code, after the original function
