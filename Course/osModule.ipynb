# %%
pwd
# Out:
# 'c:\\Users\\51ngh\\Documents\\GITHUB_Repo\\Python_basics\\Course'

# %%
f = open("practice.txt", "w+")
f.write("This is a test string")
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\51ngh\\Documents\\GITHUB_Repo\\Python_basics\\Course'

# %%
os.listdir()
# Out:
# ['args.ipynb',
#  'Chained_Comparison Operators.ipynb',
#  'Collections.ipynb',
#  'Comparison_Operators.ipynb',
#  'decorator.ipynb',
#  'Dictionaries.ipynb',
#  'ErrorsExceptions.ipynb',
#  'for_Loops.ipynb',
#  'Functions.ipynb',
#  'Generator.ipynb',
#  'if_elif_else_Statements.ipynb',
#  'LambdaMapFilter.ipynb',
#  'Lists.ipynb',
#  'List_Comprehensions.ipynb',
#  'Methods.ipynb',
#  'Modules.ipynb',
#  'NestedStatementsScope.ipynb',
#  'Numbers.ipynb',
#  'ObjectOrientedProgramming.ipynb',
#  'osModule.ipynb',
#  'practice.txt',
#  'Sets_Booleans.ipynb',
#  'Strings.ipynb',
#  'Strings_Formatting .ipynb',
#  'testfile',
#  'Tuples.ipynb',
#  'Useful-Operators.ipynb',
#  'Variable.ipynb',
#  'while_Loops.ipynb']

# %%
os.listdir("c:\\Users\\51ngh")
# Out:
# ['.anaconda',
#  '.arduinoIDE',
#  '.bash_history',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.labelImgSettings.pkl',
#  '.lim',
#  '.limpc',
#  '.matplotlib',
#  '.ms-ad',
#  '.node_repl_history',
#  '.python_history',
#  '.streamlit',
#  '.thumbnails',
#  '.trae',
#  '.trae-aicc',
#  '.vscode',
#  'anaconda3',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'CrossDevice',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'jmg',
#  'Links',
#  'Local Settings',
#  'miniforge3',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'node_modules',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{75d30fa7-f3f8-11ef-96bf-820d6ebf0d8b}.TM.blf',
#  'NTUSER.DAT{75d30fa7-f3f8-11ef-96bf-820d6ebf0d8b}.TMContainer00000000000000000001.regtrans-ms',
# ...

# %%
import shutil

# %%
shutil.move("practice.txt","c:\\Users\\51ngh\\Documents\\GITHUB_Repo\\Python_basics")
# Out:
# 'c:\\Users\\51ngh\\Documents\\GITHUB_Repo\\Python_basics\\practice.txt'

# %%
shutil.move("C:\\Users\\51ngh\\Documents\\GITHUB_Repo\\Python_basics\\practice.txt", os.getcwd())
# Out:
# 'c:\\Users\\51ngh\\Documents\\GITHUB_Repo\\Python_basics\\Course\\practice.txt'

# %%
os.listdir()
# Out:
# ['args.ipynb',
#  'Chained_Comparison Operators.ipynb',
#  'Collections.ipynb',
#  'Comparison_Operators.ipynb',
#  'decorator.ipynb',
#  'Dictionaries.ipynb',
#  'ErrorsExceptions.ipynb',
#  'for_Loops.ipynb',
#  'Functions.ipynb',
#  'Generator.ipynb',
#  'if_elif_else_Statements.ipynb',
#  'LambdaMapFilter.ipynb',
#  'Lists.ipynb',
#  'List_Comprehensions.ipynb',
#  'Methods.ipynb',
#  'Modules.ipynb',
#  'NestedStatementsScope.ipynb',
#  'Numbers.ipynb',
#  'ObjectOrientedProgramming.ipynb',
#  'osModule.ipynb',
#  'practice.txt',
#  'Sets_Booleans.ipynb',
#  'Strings.ipynb',
#  'Strings_Formatting .ipynb',
#  'testfile',
#  'Tuples.ipynb',
#  'Useful-Operators.ipynb',
#  'Variable.ipynb',
#  'while_Loops.ipynb']

# %%
import send2trash

# %%
send2trash.send2trash("practice.txt")

# %%
os.listdir()
# Out:
# ['args.ipynb',
#  'Chained_Comparison Operators.ipynb',
#  'Collections.ipynb',
#  'Comparison_Operators.ipynb',
#  'decorator.ipynb',
#  'Dictionaries.ipynb',
#  'ErrorsExceptions.ipynb',
#  'for_Loops.ipynb',
#  'Functions.ipynb',
#  'Generator.ipynb',
#  'if_elif_else_Statements.ipynb',
#  'LambdaMapFilter.ipynb',
#  'Lists.ipynb',
#  'List_Comprehensions.ipynb',
#  'Methods.ipynb',
#  'Modules.ipynb',
#  'NestedStatementsScope.ipynb',
#  'Numbers.ipynb',
#  'ObjectOrientedProgramming.ipynb',
#  'osModule.ipynb',
#  'Sets_Booleans.ipynb',
#  'Strings.ipynb',
#  'Strings_Formatting .ipynb',
#  'testfile',
#  'Tuples.ipynb',
#  'Useful-Operators.ipynb',
#  'Variable.ipynb',
#  'while_Loops.ipynb']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\51ngh\\Documents\\GITHUB_Repo\\Python_basics\\Course'

# %%
for folder, sub_folder, files in os.walk("C:\\Users\\51ngh\\Documents\\GITHUB_Repo\\Python_basics\\Course\\"):
    print(f"Currently looking at folder: {folder}")
    print("\n")
    print("The subfolders are: ")
    for sub_fold in sub_folder:
        print(f"\t Subfolder: {sub_fold}")
    print("\n")
    print("The files are: ")
    for f in files:
        print(f"\t File: {f}")
    print("\n")
# Out:
# Currently looking at folder: C:\Users\51ngh\Documents\GITHUB_Repo\Python_basics\Course\
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: args.ipynb
# 	 File: Chained_Comparison Operators.ipynb
# 	 File: Collections.ipynb
# 	 File: Comparison_Operators.ipynb
# 	 File: decorator.ipynb
# 	 File: Dictionaries.ipynb
# 	 File: ErrorsExceptions.ipynb
# 	 File: for_Loops.ipynb
# 	 File: Functions.ipynb
# 	 File: Generator.ipynb
# 	 File: if_elif_else_Statements.ipynb
# 	 File: LambdaMapFilter.ipynb
# 	 File: Lists.ipynb
# 	 File: List_Comprehensions.ipynb
# 	 File: Methods.ipynb
# 	 File: Modules.ipynb
# 	 File: NestedStatementsScope.ipynb
# 	 File: Numbers.ipynb
# 	 File: ObjectOrientedProgramming.ipynb
# 	 File: osModule.ipynb
# 	 File: Sets_Booleans.ipynb
# 	 File: Strings.ipynb
# 	 File: Strings_Formatting .ipynb
# 	 File: testfile
# 	 File: Tuples.ipynb
# 	 File: Useful-Operators.ipynb
# 	 File: Variable.ipynb
# 	 File: while_Loops.ipynb
