# %%
a= input("Enter ur name:")
b= input("Enter ur age:")
print(f"my name is {a} and my age is {b}")
# Out:
# my name is dfskjh and my age is 65'

# %%
if a =="utkarsh":
    print("true")
else:
    print("false")
# Out:
# false

# %%
s1 = "Naman is a boy "
s2 = "naman"
s1==s2
s1.split()
# Out:
# ['Naman', 'is', 'a', 'boy']

# %%
l =[]
print(type(l))
# Out:
# <class 'list'>

# %%
l = [1,2,3,4,5,2]
l.append(6)
print(l)
l.pop()
print(l)
l.insert(2,8)
print(l)    
t1=tuple(l)
print(t1)
print(type(t1))
# Out:
# [1, 2, 3, 4, 5, 2, 6]
# [1, 2, 3, 4, 5, 2]
# [1, 2, 8, 3, 4, 5, 2]
# (1, 2, 8, 3, 4, 5, 2)
# <class 'tuple'>
